# %% [markdown]
# task 1

# %%
kjhjdkshf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 kjhjdkshf
#
# NameError: name 'kjhjdkshf' is not defined

# %% [markdown]
# task 2

# %%
idsifuidsf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 idsifuidsf
#
# NameError: name 'idsifuidsf' is not defined
